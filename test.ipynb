# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd

# SSL 옵션을 명시하지 않고 MongoDB에 연결
client = MongoClient("mongodb+srv://mafumafu9854:3eWoSwhmDvhlim9L@cluster0.nxdfqvk.mongodb.net/?retryWrites=true&w=majority")

try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")

    # MongoDB 데이터 불러오기
    db = client['eat_croll']
    collection = db['eat_croll_data']
    documents = list(collection.find({}))

    # 데이터프레임으로 변환
    data = pd.DataFrame(documents)

    # CSV 파일로 저장
    data.to_csv('eat_croll_data.csv', index=False, encoding='utf-8-sig')

    print("Data saved as 'eat_croll_data.csv'.")

except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# Data saved as 'eat_croll_data.csv'.

# %%
client = MongoClient("mongodb+srv://mafumafu9854:3eWoSwhmDvhlim9L@cluster0.nxdfqvk.mongodb.net/?retryWrites=true&w=majority")
client.admin.command('ping')
print("Successfully connected to MongoDB!")
db = client['eat_croll']
collection = db['eat_croll_data']
documents = list(collection.find({}))
data = pd.DataFrame(documents)
data_sorted = data.sort_values(by='날짜')
data_sorted['낙찰률'] = data_sorted['낙찰예정가격'] * data_sorted['낙찰방식'] / (data_sorted['기초가격'] + 0.0001)
data_sorted = data_sorted[data_sorted['낙찰률'] < 1000]
data_sorted = data_sorted[data_sorted['날짜'] >= '2000-01-01']
data_sorted['발주처_id'] = data_sorted['발주처'].astype('category').cat.codes

data_sorted
# Out:
# Successfully connected to MongoDB!
#                             _id                  날짜        기초가격      발주처  \
# 19019  65291e35394129e582fcb8fe 2018-01-02 11:00:00   9962000.0   통영초등학교
# 19017  65291e2f394129e582fcb8fc 2018-01-03 11:00:00   3995140.0   북성초등학교
# 19016  65291e2d394129e582fcb8fb 2018-01-04 09:00:00   7325965.0   용남고등학교
# 19018  65291e32394129e582fcb8fd 2018-01-08 11:00:00   3497600.0   제석초등학교
# 19015  65291e2a394129e582fcb8fa 2018-01-08 13:00:00  11012200.0  삼정자초등학교
# ...                         ...                 ...         ...      ...
# 28204  6557198d8f4cf17c899627be 2023-11-17 11:00:00   1380530.0   명석초등학교
# 28201  6557197d8f4cf17c899627bb 2023-11-17 11:00:00   4520590.0   대성초등학교
# 28200  655719788f4cf17c899627ba 2023-11-17 11:00:00   6334420.0   서남초등학교
# 28210  655719ac8f4cf17c899627c4 2023-11-17 11:00:00   5787960.0   문산초등학교
# 28222  65571a1f8f4cf17c899627d0 2023-11-17 11:30:00   2552190.0   봉곡초등학교
#
#        낙찰방식      낙찰예정가격                                               공고건명  \
# 19019  90.0   9842426.0       2018년 1-2월 통영초등학교 급식품(육류) 구매 소액수의 견적제출 안내 공고
# 19017  90.0   3909426.0             2018년 1-2월분 학교급식용 육류 구매 소액수의 견적 공고(긴급)
# 19016  90.0   7249415.0                            용남고등학교 1,2월 급식 식재료 (육류)
# 19018  90.0   3477565.0      2018. 1~2월 제석초등학교 급식품(육류) 구매 소액수의 견적 제출 안내 공고
# 19015  90.0  10904145.0          삼정자초등학교 2018학년도 1~2월 학교급식물품(육류)소액수의 견적 공고
# ...     ...         ...                                                ...
# 28204  90.0   1383047.0     명석초등학교 2023년 12월~2024년 1월 육류 구매 소액수의 견적제출 안내공고
# 28201  90.0   4501334.0  대성초등학교 2023년 12월-2024년1,2월 학교급식용 식자재(육류축산물) 구매...
# 28200  90.0   6332442.0  서남초등학교 2023학년도 12-2월 학교급식품(육류) 구매 2인이상 수의견적 제출...
# 28210  90.0   5745029.0                   2023년 12월~ 2024년 1월 학교급식품(육류) 구입
# 28222  90.0   2539472.0  2023년 12월~2024년 2월 봉곡초등학교 급식품(축산물군) 구매 소액수의 견적...
#
#                                                       지역  \
# 19019  {'도/특별시/광역시': '경상남도', '시/군/구': '통영시', '읍/면/동/도...
# 19017  {'도/특별시/광역시': '경상남도', '시/군/구': '창원시', '읍/면/동/도...
# 19016  {'도/특별시/광역시': '경상남도', '시/군/구': '사천시', '읍/면/동/도...
# 19018  {'도/특별시/광역시': '경상남도', '시/군/구': '통영시', '읍/면/동/도...
# 19015  {'도/특별시/광역시': '경상남도', '시/군/구': '창원시', '읍/면/동/도...
# ...                                                  ...
# 28204  {'도/특별시/광역시': '경상남도', '시/군/구': '진주시', '읍/면/동/도...
# 28201  {'도/특별시/광역시': '경상남도', '시/군/구': '사천시', '읍/면/동/도...
# 28200  {'도/특별시/광역시': '경상남도', '시/군/구': '양산시', '읍/면/동/도...
# 28210  {'도/특별시/광역시': '경상남도', '시/군/구': '진주시', '읍/면/동/도...
# 28222  {'도/특별시/광역시': '경상남도', '시/군/구': '진주시', '읍/면/동/도...
#
#                                                     낙찰업체        낙찰률  발주처_id
# 19019  [{'업체명': '순우리 주식회사', '순위': '1', '입찰금액': 885950...  88.919729     850
# 19017  [{'업체명': '순우리 주식회사', '순위': '1', '입찰금액': 356160...  88.069089     419
# 19016  [{'업체명': '(주)진주축산', '순위': '1', '입찰금액': 6524600...  89.059578     589
# 19018  [{'업체명': '(주)프라임푸드시스템', '순위': '1', '입찰금액': 313...  89.484461     696
# 19015  [{'업체명': '순우리 주식회사', '순위': '1', '입찰금액': 981950...  89.116893     455
# ...                                                  ...        ...     ...
# 28204  [{'업체명': '대경식품', '순위': '1', '입찰금액': 1245640, '...  90.164089     348
# 28201  [{'업체명': '태웅축산(주)', '순위': '1', '입찰금액': 4051800...  89.616634     249
# 28200  [{'업체명': '장원유통', '순위': '1', '입찰금액': 5699300, '...  89.971896     477
# 28210  [{'업체명': '수창푸드 주식회사', '순위': '1', '입찰금액': 51720...  89.332444     365
# 28222  [{'업체명': '태웅축산(주)', '순위': '1', '입찰금액': 2286300...  89.551515     401
#
# [25208 rows x 11 columns]

# %%
import datetime

current_year = datetime.datetime.now().year
current_month = datetime.datetime.now().month
print(current_year, current_month)
